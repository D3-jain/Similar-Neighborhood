# %% [markdown]
# ## **Importing Required Libraries**

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from sklearn.cluster import KMeans
import json
from pandas.io.json import json_normalize
import numpy as np
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors

# %% [markdown]
# ## **Web Scrapping from the given Website**

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data['features']

# %%
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 
neighborhoods = pd.DataFrame(columns=column_names)

# %%
for data in neighborhoods_data:
    borough = data['properties']['borough'] 
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)
neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %%
ny_lat = 40.7896239
ny_long = -73.9598939

# %%
manhattan_data = neighborhoods[neighborhoods['Borough'] == 'Manhattan'].reset_index(drop=True)
manhattan_data
# Out:
#       Borough         Neighborhood   Latitude  Longitude
# 0   Manhattan          Marble Hill  40.876551 -73.910660
# 1   Manhattan            Chinatown  40.715618 -73.994279
# 2   Manhattan   Washington Heights  40.851903 -73.936900
# 3   Manhattan               Inwood  40.867684 -73.921210
# 4   Manhattan     Hamilton Heights  40.823604 -73.949688
# 5   Manhattan       Manhattanville  40.816934 -73.957385
# 6   Manhattan       Central Harlem  40.815976 -73.943211
# 7   Manhattan          East Harlem  40.792249 -73.944182
# 8   Manhattan      Upper East Side  40.775639 -73.960508
# 9   Manhattan            Yorkville  40.775930 -73.947118
# 10  Manhattan           Lenox Hill  40.768113 -73.958860
# 11  Manhattan     Roosevelt Island  40.762160 -73.949168
# 12  Manhattan      Upper West Side  40.787658 -73.977059
# 13  Manhattan       Lincoln Square  40.773529 -73.985338
# 14  Manhattan              Clinton  40.759101 -73.996119
# ...

# %%
#@title Foursquare Credential  Details
CLIENT_ID = 'NEXNZCPOJKXT3KJIJDBFBCCG5GKTUXSRKWNYILIBGHS1CJ5I'
CLIENT_SECRET = 'OJLKTAJEHJT5GRQF22H1D3YWW3QOY42EKCWWML0BPP10NZ1A'
VERSION = '20180605'
LIMIT = 100

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
manhattan_venues = getNearbyVenues(names=manhattan_data['Neighborhood'],
                                   latitudes=manhattan_data['Latitude'],
                                   longitudes=manhattan_data['Longitude']
                                  )
# Out:
# Marble Hill
# Chinatown
# Washington Heights
# Inwood
# Hamilton Heights
# Manhattanville
# Central Harlem
# East Harlem
# Upper East Side
# Yorkville
# Lenox Hill
# Roosevelt Island
# Upper West Side
# Lincoln Square
# Clinton
# Midtown
# Murray Hill
# Chelsea
# Greenwich Village
# East Village
# Lower East Side
# Tribeca
# Little Italy
# Soho
# West Village
# Manhattan Valley
# Morningside Heights
# Gramercy
# Battery Park City
# Financial District
# Carnegie Hill
# Noho
# Civic Center
# Midtown South
# Sutton Place
# Turtle Bay
# Tudor City
# Stuyvesant Town
# Flatiron
# Hudson Yards

# %%
manhattan_onehot = pd.get_dummies(manhattan_venues[['Venue Category']], prefix="", prefix_sep="")
manhattan_onehot['Neighbourhood'] = manhattan_venues['Neighbourhood']
fixed_columns = [manhattan_onehot.columns[-1]] + list(manhattan_onehot.columns[:-1])
manhattan_onehot = manhattan_onehot[fixed_columns]
manhattan_onehot.head()
# Out:
#   Neighbourhood  Accessories Store  ...  Women's Store  Yoga Studio
# 0   Marble Hill                  0  ...              0            0
# 1   Marble Hill                  0  ...              0            1
# 2   Marble Hill                  0  ...              0            0
# 3   Marble Hill                  0  ...              0            0
# 4   Marble Hill                  0  ...              0            0
#
# [5 rows x 330 columns]

# %%
manhattan_grouped = manhattan_onehot.groupby('Neighbourhood').mean().reset_index()
manhattan_grouped
# Out:
#           Neighbourhood  Accessories Store  ...  Women's Store  Yoga Studio
# 0     Battery Park City           0.000000  ...       0.000000     0.000000
# 1         Carnegie Hill           0.000000  ...       0.000000     0.035714
# 2        Central Harlem           0.000000  ...       0.000000     0.000000
# 3               Chelsea           0.000000  ...       0.010000     0.000000
# 4             Chinatown           0.000000  ...       0.000000     0.000000
# 5          Civic Center           0.000000  ...       0.000000     0.032967
# 6               Clinton           0.000000  ...       0.000000     0.000000
# 7           East Harlem           0.000000  ...       0.000000     0.000000
# 8          East Village           0.000000  ...       0.000000     0.000000
# 9    Financial District           0.000000  ...       0.010000     0.010000
# 10             Flatiron           0.000000  ...       0.010204     0.020408
# ...

# %%
source = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
soup = BeautifulSoup(source,'lxml')
req_table = soup.find('table',class_='wikitable sortable')
table_rows = req_table.find_all('tr')
l = []
for tr in table_rows:
  td = tr.find_all('td')
  row = [tr.text for tr in td]
  l.append(row)
l.remove([])
df = pd.DataFrame(l, columns=["Postal Code", "Borough","Neighborhood"])
df
# Out:
#     Postal Code  ...                                       Neighborhood
# 0         M1A\n  ...                                                 \n
# 1         M2A\n  ...                                                 \n
# 2         M3A\n  ...                                        Parkwoods\n
# 3         M4A\n  ...                                 Victoria Village\n
# 4         M5A\n  ...                        Regent Park, Harbourfront\n
# ..          ...  ...                                                ...
# 175       M5Z\n  ...                                                 \n
# 176       M6Z\n  ...                                                 \n
# 177       M7Z\n  ...                                                 \n
# 178       M8Z\n  ...  Mimico NW, The Queensway West, South of Bloor,...
# 179       M9Z\n  ...                                                 \n
#
# [180 rows x 3 columns]

# %% [markdown]
# # **Cleaning DataFrame**

# %%
for ind in df.index:
  df['Postal Code'][ind] = df['Postal Code'][ind].replace('\n','')
  df['Borough'][ind] = df['Borough'][ind].replace('\n','')
  df['Neighborhood'][ind] = df['Neighborhood'][ind].replace('\n','')
  df['Neighborhood'][ind] = df['Neighborhood'][ind].replace('/',',')
df
# Out:
#     Postal Code  ...                                       Neighborhood
# 0           M1A  ...
# 1           M2A  ...
# 2           M3A  ...                                          Parkwoods
# 3           M4A  ...                                   Victoria Village
# 4           M5A  ...                          Regent Park, Harbourfront
# ..          ...  ...                                                ...
# 175         M5Z  ...
# 176         M6Z  ...
# 177         M7Z  ...
# 178         M8Z  ...  Mimico NW, The Queensway West, South of Bloor,...
# 179         M9Z  ...
#
# [180 rows x 3 columns]

# %% [markdown]
# ## **Size of DataFrame using .shape**

# %%
df.shape
# Out:
# (180, 3)

# %% [markdown]
# ## **Reading CSV File for Coordinates**

# %%
df2 = pd.read_csv('http://cocl.us/Geospatial_data')
df2
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# ..          ...        ...        ...
# 98          M9N  43.706876 -79.518188
# 99          M9P  43.696319 -79.532242
# 100         M9R  43.688905 -79.554724
# 101         M9V  43.739416 -79.588437
# 102         M9W  43.706748 -79.594054
#
# [103 rows x 3 columns]

# %% [markdown]
# ## **Merging the two Data Frame**

# %%
df = pd.merge(df,df2,on='Postal Code')
df
# Out:
#     Postal Code           Borough  ...   Latitude  Longitude
# 0           M3A        North York  ...  43.753259 -79.329656
# 1           M4A        North York  ...  43.725882 -79.315572
# 2           M5A  Downtown Toronto  ...  43.654260 -79.360636
# 3           M6A        North York  ...  43.718518 -79.464763
# 4           M7A  Downtown Toronto  ...  43.662301 -79.389494
# ..          ...               ...  ...        ...        ...
# 98          M8X         Etobicoke  ...  43.653654 -79.506944
# 99          M4Y  Downtown Toronto  ...  43.665860 -79.383160
# 100         M7Y      East Toronto  ...  43.662744 -79.321558
# 101         M8Y         Etobicoke  ...  43.636258 -79.498509
# 102         M8Z         Etobicoke  ...  43.628841 -79.520999
#
# [103 rows x 5 columns]

# %%
for x in df.index:
  if (df['Borough'][x].find('Toronto')==-1):
    df.drop(x,inplace=True)
df.reset_index(inplace=True)
df = df.drop(['index'], axis = 1)
df.drop(df.columns[[0]], axis = 1, inplace = True)
df
# Out:
#              Borough  ...  Longitude
# 0   Downtown Toronto  ... -79.360636
# 1   Downtown Toronto  ... -79.389494
# 2   Downtown Toronto  ... -79.378937
# 3   Downtown Toronto  ... -79.375418
# 4       East Toronto  ... -79.293031
# 5   Downtown Toronto  ... -79.373306
# 6   Downtown Toronto  ... -79.387383
# 7   Downtown Toronto  ... -79.422564
# 8   Downtown Toronto  ... -79.384568
# 9       West Toronto  ... -79.442259
# 10  Downtown Toronto  ... -79.381752
# 11      West Toronto  ... -79.419750
# 12      East Toronto  ... -79.352188
# 13  Downtown Toronto  ... -79.381576
# 14      West Toronto  ... -79.428191
# 15      East Toronto  ... -79.315572
# 16  Downtown Toronto  ... -79.379817
# 17      East Toronto  ... -79.340923
# 18   Central Toronto  ... -79.388790
# 19   Central Toronto  ... -79.416936
# 20   Central Toronto  ... -79.390197
# 21   Central Toronto  ... -79.411307
# 22      West Toronto  ... -79.464763
# 23   Central Toronto  ... -79.405678
# ...

# %%
sim_df = df.append(manhattan_data)
sim_df
# Out:
#              Borough  ...  Longitude
# 0   Downtown Toronto  ... -79.360636
# 1   Downtown Toronto  ... -79.389494
# 2   Downtown Toronto  ... -79.378937
# 3   Downtown Toronto  ... -79.375418
# 4       East Toronto  ... -79.293031
# ..               ...  ...        ...
# 35         Manhattan  ... -73.967708
# 36         Manhattan  ... -73.971219
# 37         Manhattan  ... -73.974052
# 38         Manhattan  ... -73.990947
# 39         Manhattan  ... -74.000111
#
# [79 rows x 4 columns]

# %% [markdown]
# ## **Obtain Nearby Venues**

# %%
torronto_venues = getNearbyVenues(names=df['Neighborhood'],
                                   latitudes=df['Latitude'],
                                   longitudes=df['Longitude']
                                  )
# Out:
# Regent Park, Harbourfront
# Queen's Park, Ontario Provincial Government
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King
# Dufferin, Dovercourt Village
# Harbourfront East, Union Station, Toronto Islands
# Little Portugal, Trinity
# The Danforth West, Riverdale
# Toronto Dominion Centre, Design Exchange
# Brockton, Parkdale Village, Exhibition Place
# India Bazaar, The Beaches West
# Commerce Court, Victoria Hotel
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill North & West
# High Park, The Junction South
# North Toronto West
# The Annex, North Midtown, Yorkville
# Parkdale, Roncesvalles
# Davisville
# University of Toronto, Harbord
# Runnymede, Swansea
# Moore Park, Summerhill East
# Kensington Market, Chinatown, Grange Park
# Summerhill West, Rathnelly, South Hill, Forest Hill SE, Deer Park
# ...

# %%
torronto_venues.head()
# Out:
#                Neighbourhood  ...       Venue Category
# 0  Regent Park, Harbourfront  ...               Bakery
# 1  Regent Park, Harbourfront  ...          Coffee Shop
# 2  Regent Park, Harbourfront  ...       Breakfast Spot
# 3  Regent Park, Harbourfront  ...  Distribution Center
# 4  Regent Park, Harbourfront  ...                  Spa
#
# [5 rows x 7 columns]

# %% [markdown]
# ## **To list various Venue Category for each Neighborhood**

# %%
torronto_onehot = pd.get_dummies(torronto_venues[['Venue Category']], prefix="", prefix_sep="")
torronto_onehot['Neighbourhood'] = torronto_venues['Neighbourhood']
fixed_columns = [torronto_onehot.columns[-1]] + list(torronto_onehot.columns[:-1])
torronto_onehot = torronto_onehot[fixed_columns]
torronto_onehot.head()
# Out:
#                Neighbourhood  Afghan Restaurant  ...  Women's Store  Yoga Studio
# 0  Regent Park, Harbourfront                  0  ...              0            0
# 1  Regent Park, Harbourfront                  0  ...              0            0
# 2  Regent Park, Harbourfront                  0  ...              0            0
# 3  Regent Park, Harbourfront                  0  ...              0            0
# 4  Regent Park, Harbourfront                  0  ...              0            0
#
# [5 rows x 237 columns]

# %% [markdown]
# ## **To group the Neighborhoods and Calculate Mean**

# %%
torronto_grouped = torronto_onehot.groupby('Neighbourhood').mean().reset_index()
torronto_grouped
final_df = torronto_grouped.append(manhattan_grouped)
final_df = final_df.fillna(0)
final_df
# Out:
#                                         Neighbourhood  ...  Wine Shop
# 0                                         Berczy Park  ...   0.000000
# 1        Brockton, Parkdale Village, Exhibition Place  ...   0.000000
# 2               Business reply mail Processing Centre  ...   0.000000
# 3   CN Tower, King and Spadina, Railway Lands, Har...  ...   0.000000
# 4                                  Central Bay Street  ...   0.000000
# ..                                                ...  ...        ...
# 35                                    Upper East Side  ...   0.035294
# 36                                    Upper West Side  ...   0.014286
# 37                                 Washington Heights  ...   0.022472
# 38                                       West Village  ...   0.010000
# 39                                          Yorkville  ...   0.030000
#
# [79 rows x 376 columns]

# %% [markdown]
# ## **Function To Return Most Common Venues**

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# ## **Calling Above Fuction using Grouped DataFrame obtained**

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighbourhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = final_df['Neighbourhood']

for ind in np.arange(final_df.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(final_df.iloc[ind, :], num_top_venues)
neighborhoods_venues_sorted.head()
# Out:
#                                        Neighbourhood  ... 10th Most Common Venue
# 0                                        Berczy Park  ...              Irish Pub
# 1       Brockton, Parkdale Village, Exhibition Place  ...          Burrito Place
# 2              Business reply mail Processing Centre  ...             Skate Park
# 3  CN Tower, King and Spadina, Railway Lands, Har...  ...     Airport Food Court
# 4                                 Central Bay Street  ...                    Bar
#
# [5 rows x 11 columns]

# %% [markdown]
# ## **Clustering the Data**

# %%
kclusters = 8

grouped_clustering = final_df.drop('Neighbourhood', 1)
# # run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(grouped_clustering)

# # check cluster labels generated for each row in the dataframe
kmeans.labels_[0:20]
# Out:
# array([2, 2, 2, 2, 7, 2, 7, 7, 7, 0, 2, 7, 6, 7, 7, 2, 7, 2, 3, 2],
#       dtype=int32)

# %% [markdown]
# ## **Adding Cluster Labels**

# %%
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %% [markdown]
# ## **Merging Clustered DataFrame with Data Frame With Location**

# %%
merged = sim_df
merged = merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighborhood')
merged
# Out:
#              Borough  ...    10th Most Common Venue
# 0   Downtown Toronto  ...             Historic Site
# 1   Downtown Toronto  ...             Burrito Place
# 2   Downtown Toronto  ...          Ramen Restaurant
# 3   Downtown Toronto  ...            Lingerie Store
# 4       East Toronto  ...                Hobby Shop
# ..               ...  ...                       ...
# 35         Manhattan  ...                   Dog Run
# 36         Manhattan  ...                       Bar
# 37         Manhattan  ...               Gas Station
# 38         Manhattan  ...  Mediterranean Restaurant
# 39         Manhattan  ...                       Gym
#
# [79 rows x 15 columns]

# %%
torronto_merged = merged[merged['Borough']!='Manhattan']
manhattan_merged = merged[merged['Borough']=='Manhattan']

# %% [markdown]
# ## **Visualizing the obtained Clusters**

# %%
#Set Color Scheme for Clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# %%
#Visualising Data Set before Clustering
latitude = 43.6532
longitude = -79.3832
torronto_unclustered = folium.Map(location=[latitude, longitude], zoom_start=12)
for lat, lon, poi in zip(df['Latitude'], df['Longitude'], df['Neighborhood']):
    label = folium.Popup(str(poi), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='yellow',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7).add_to(torronto_unclustered)
torronto_unclustered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Visualising Data Set after Clustering
latitude = 43.6532
longitude = -79.3832
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)
# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(torronto_merged['Latitude'], torronto_merged['Longitude'], torronto_merged['Neighborhood'], torronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Visualising Data Set before Clustering
latitude = 40.7831
longitude = -73.9712
unclustered = folium.Map(location=[latitude, longitude], zoom_start=12)
for lat, lon, poi in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(str(poi), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='yellow',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7).add_to(unclustered)
unclustered
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Visualising Data Set after Clustering
latitude = 40.7831
longitude = -73.9712
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(manhattan_merged['Latitude'], manhattan_merged['Longitude'], manhattan_merged['Neighborhood'], manhattan_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
